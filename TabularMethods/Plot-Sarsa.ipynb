# %%
import matplotlib.pyplot as plt


rand = []
episodes_rand = []
count = 0
ten_value_sarsa = []
episodes_ten_value_sarsa = []
ten_value_q = []
episodes_ten_value_q = []
optim_sarsa = []
episodes_optim_sarsa = []
optim_q = []
episodes_optim_q = []

with open('rand.txt') as f:
    for line in f:
        rand.append(float(line.strip()))
        episodes_rand.append(count*100)
        count += 1
print(count)

count=0
with open('10 v Q-Learning.txt') as f:
    for line in f:
        ten_value_q.append(float(line.strip()))
        episodes_ten_value_q.append(count*100)
        count += 1
print(count)

count=0
with open('10 v sarsa.txt') as f:
    for line in f:
        ten_value_sarsa.append(float(line.strip()))
        episodes_ten_value_sarsa.append(count*100)
        count += 1
print(count)

count=0
with open('Optimized Q-Learning.txt') as f:
    for line in f:
        optim_q.append(float(line.strip()))
        episodes_optim_q.append(count*100)
        count += 1
print(count)

count=0
with open('Optimized Sarsa.txt') as f:
    for line in f:
        optim_sarsa.append(float(line.strip()))
        episodes_optim_sarsa.append(count*100)
        count += 1
print(count)

# count=0
# with open('C:/Users/yonat/OneDrive/Desktop/Reinforcment Learning/Project/DQN-0.002-64-64.txt') as f:
#     for line in f:
#         line = line.split('=')
#        # line[2] = line[2].split(',')
#         #print(float(line[2][0].strip()))
#         lr_2.append(float(line[3].strip()))
#         episodes_2.append(count)
#         count += 1
# print(count)

fig = plt.figure(figsize=[15,10])
ax = fig.add_subplot(111)
ax.set_title("Acquired Rewards")
plt.plot(episodes_rand, rand, 'k', label='Random Policy')
plt.plot(episodes_ten_value_q, ten_value_q, 'r', label='10 value Q-Learning')
plt.plot(episodes_ten_value_sarsa, ten_value_sarsa, 'g', label='10 value SARSA')
plt.plot(episodes_optim_q, optim_q, 'b', label='Optimized Discrete Q-Learning')
plt.plot(episodes_optim_sarsa, optim_sarsa, 'm', label='Optimized Discrete SARSA')
#plt.plot(episodes_2, lr_2, 'b', label='DQN with lr = 0.002')
plt.grid()
ax.set_xlabel("episodes")
ax.set_ylabel("Average Reward")
ax.legend(loc='best')
plt.savefig('tabular_methods_rewards.png')
plt.show()
# Out:
# 100
# 100
# 100
# 100
# 100
